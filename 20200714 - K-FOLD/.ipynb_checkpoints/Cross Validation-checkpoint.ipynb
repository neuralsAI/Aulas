# %% [markdown]
# <strong><h1>Cross validation</h1></strong>

# %% [markdown]
# <strong> <h2>Carregar libs</h2></strong>

# %%
import pandas as pd
from sklearn import tree
from sklearn.model_selection import cross_val_score

# %% [markdown]
# <strong><h2>Carregar dataset</h2></strong>

# %% [markdown]
# <p>O dataset a ser utilisado ranquea as universidades do mundo do ano de 2012, e inclue os seguintes dados:</p>
# <ul>
#     <li>world_rank</li>
#     <li>institution</li>
#     <li>country</li>
#     <li>national_rank</li>
#     <li>quality_of_education</li>
#     <li>alumni_employment</li>
#     <li>quality_of_faculty</li>
#     <li>publications</li>
#     <li>influence</li>
#     <li>citations</li>
#     <li>broad_impact</li>
#     <li>patents</li>
#     <li>score</li>
#     <li>year</li>
# </ul>

# %%
#Ler o dataset
df = pd.read_csv('./data/datasets_27_792993_cwurData.csv')
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# 0             1          1          1           NaN        5  100.00  2012
# 1            12          4          4           NaN        1   91.67  2012
# 2             4          2          2           NaN       15   89.50  2012
# 3            16         16         11           NaN       50   86.17  2012
# 4            37         22         22           NaN       18   85.21  2012

# %%
pd.isnull(df).any()
# Out:
# world_rank              False
# institution             False
# country                 False
# national_rank           False
# quality_of_education    False
# alumni_employment       False
# quality_of_faculty      False
# publications            False
# influence               False
# citations               False
# broad_impact             True
# patents                 False
# score                   False
# year                    False
# dtype: bool

# %% [markdown]
# <Strong><h2>Preparo dos dados</h2></Strong>

# %%
df_selected = df.drop(['broad_impact', 'year', 'institution'], axis=1)
df_selected.head()
# Out:
#    world_rank         country  national_rank  quality_of_education  \
# 0           1             USA              1                     7
# 1           2             USA              2                     9
# 2           3             USA              3                    17
# 3           4  United Kingdom              1                    10
# 4           5             USA              4                     2
#
#    alumni_employment  quality_of_faculty  publications  influence  citations  \
# 0                  9                   1             1          1          1
# 1                 17                   3            12          4          4
# 2                 11                   5             4          2          2
# 3                 24                   4            16         16         11
# 4                 29                   7            37         22         22
#
#    patents   score
# 0        5  100.00
# 1        1   91.67
# 2       15   89.50
# 3       50   86.17
# 4       18   85.21

# %%
# encode "country"
from sklearn.preprocessing import LabelEncoder
labelEncoder_X = LabelEncoder()
df_selected.country = labelEncoder_X.fit_transform(df_selected.country)

df_selected.head()
# Out:
#    world_rank  country  national_rank  quality_of_education  \
# 0           1       54              1                     7
# 1           2       54              2                     9
# 2           3       54              3                    17
# 3           4       57              1                    10
# 4           5       54              4                     2
#
#    alumni_employment  quality_of_faculty  publications  influence  citations  \
# 0                  9                   1             1          1          1
# 1                 17                   3            12          4          4
# 2                 11                   5             4          2          2
# 3                 24                   4            16         16         11
# 4                 29                   7            37         22         22
#
#    patents   score
# 0        5  100.00
# 1        1   91.67
# 2       15   89.50
# 3       50   86.17
# 4       18   85.21

# %%
df_selected['score'] = df_selected['score'].astype('int')
df_selected.head()
# Out:
#    world_rank  country  national_rank  quality_of_education  \
# 0           1       54              1                     7
# 1           2       54              2                     9
# 2           3       54              3                    17
# 3           4       57              1                    10
# 4           5       54              4                     2
#
#    alumni_employment  quality_of_faculty  publications  influence  citations  \
# 0                  9                   1             1          1          1
# 1                 17                   3            12          4          4
# 2                 11                   5             4          2          2
# 3                 24                   4            16         16         11
# 4                 29                   7            37         22         22
#
#    patents  score
# 0        5    100
# 1        1     91
# 2       15     89
# 3       50     86
# 4       18     85

# %%
from sklearn.model_selection import train_test_split
X = df_selected.drop(['score'], axis=1)
Y = df_selected['score']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.3,random_state=1)
clf = tree.DecisionTreeClassifier()
clf.fit(X_train, Y_train)

# Testing Data
predictions = clf.predict(X_test)
    
# Evaluating score
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
print("Test Accuracy score: ",accuracy_score(Y_test,predictions))
print("Classification report: ")
print(classification_report(Y_test,predictions))
# Out:
# Test Accuracy score:  0.8242424242424242
# Classification report:
#               precision    recall  f1-score   support
#
#           43       0.00      0.00      0.00         1
#           44       0.98      0.99      0.99       293
#           45       0.96      0.97      0.96       117
#           46       0.83      0.83      0.83        48
#           47       0.71      0.88      0.79        42
#           48       0.81      0.81      0.81        27
#           49       0.74      0.74      0.74        23
#           50       0.45      0.50      0.48        10
#           51       0.43      0.16      0.23        19
#           52       0.30      0.25      0.27        12
#           53       0.22      0.20      0.21        10
#           54       0.33      0.17      0.22         6
#           55       0.17      0.50      0.25         2
#           56       0.25      0.20      0.22         5
#           57       0.50      0.50      0.50         2
#           58       0.00      0.00      0.00         4
#           59       0.29      0.67      0.40         3
#           60       0.00      0.00      0.00         1
#           61       0.00      0.00      0.00         2
#           62       0.50      0.50      0.50         2
#           63       0.00      0.00      0.00         2
#           64       0.00      0.00      0.00         0
#           65       0.00      0.00      0.00         1
#           66       0.00      0.00      0.00         3
#           67       0.00      0.00      0.00         1
#           68       0.00      0.00      0.00         3
#           69       0.00      0.00      0.00         0
#           72       0.00      0.00      0.00         0
#           73       1.00      1.00      1.00         1
#           76       0.00      0.00      0.00         0
#           77       0.00      0.00      0.00         2
#           78       0.00      0.00      0.00         1
#           79       0.00      0.00      0.00         1
#           80       0.00      0.00      0.00         0
#           82       0.50      0.50      0.50         2
#           85       0.00      0.00      0.00         1
#           86       0.00      0.00      0.00         3
#           88       0.00      0.00      0.00         0
#           89       0.00      0.00      0.00         1
#           90       0.00      0.00      0.00         1
#           91       0.00      0.00      0.00         0
#           92       0.00      0.00      0.00         1
#           96       0.00      0.00      0.00         2
#           97       0.00      0.00      0.00         1
#           98       0.00      0.00      0.00         1
#           99       0.00      0.00      0.00         1
#          100       1.00      1.00      1.00         2
#
#     accuracy                           0.82       660
#    macro avg       0.23      0.24      0.23       660
# weighted avg       0.81      0.82      0.82       660
# /home/joao/anaconda3/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/joao/anaconda3/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# K-fold (k=5)
scores = cross_val_score(clf, X, Y, cv=5, scoring='accuracy')
scores
# Out:
# /home/joao/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# array([0.65454545, 0.88636364, 0.45227273, 0.65      , 0.8       ])

# %%
# Results
print("Accuracy: %0.2f" % (scores.mean()))
print("------------")
print()
# Out:
# Accuracy: 0.69
# ------------

# %% [markdown]
# <Strong><h2>Exemplo de LOOCV</h2></Strong>

# %%
from sklearn.model_selection import LeaveOneOut
loo = LeaveOneOut()
scores = cross_val_score(clf, X, Y, cv=loo, scoring='accuracy')
print("Accuracy: %0.2f" % (scores.mean()))
# Out:
# Accuracy: 0.84

# %% [markdown]
# <Strong><h2>Exemplo de K-fold Repeated</h2></Strong>

# %%
from sklearn.model_selection import ShuffleSplit
kfold2 = ShuffleSplit(n_splits=10, test_size=0.30, random_state=1)
scores = cross_val_score(clf, X, Y, cv=kfold2, scoring='accuracy')
scores
# Out:
# array([0.82575758, 0.85606061, 0.82272727, 0.83484848, 0.81818182,
#        0.8469697 , 0.80454545, 0.84090909, 0.83484848, 0.83939394])

# %%
print("Accuracy: %0.2f" % (scores.mean()))
# Out:
# Accuracy: 0.83
